# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanicka2/flyrank_mlengineer/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Amanicka2/flyrank_mlengineer/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Lane 2: Refresh / Content Opportunity Scoring

#I chose this lane because it allows me to build an end-to-end machine learning system that solves a practical business problem: helping a content team identify which pages should be reviewed first. It combines exploratory data analysis, feature engineering, supervised machine learning, validation, and ranking into one project, while producing a useful decision-support output rather than just a model prediction.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# This model helps content managers and SEO specialists decide which web pages to review first when facing limited time and thousands of candidates. Rather than relying on overall prediction accuracy, the system generates a ranked priority list to guide human investigation toward the most promising pages. Getting this call wrong carries distinct trade-offs: a false positive wastes a reviewer's valuable time on a page that isn't actually declining, while a false negative means missing an early opportunity to intervene on a weakening page. Ultimately, the objective is to optimize human review efficiency by surfacing high-impact candidates first.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import pandas as pd

# Clone the repo if it hasn't been cloned into Colab yet
if not os.path.exists('flyrank_mlengineer'):
    # !git clone https://github.com/Amanicka2/flyrank_mlengineer.git

# Set path to the CSV inside the cloned repository
csv_path = 'flyrank_mlengineer/data/raw/content_refresh_anonymized.csv'

# Load the dataset
df = pd.read_csv(csv_path)

# Calculate metrics
total_pages = len(df)
declining_pages = (df['trend_direction'] == 'down').sum()
pct_declining = (declining_pages / total_pages) * 100
avg_impressions = df['impressions_90d'].mean()

# Output results
print(f"Total pages in starter dataset: {total_pages:,}")
print(f"Pages with declining traffic trend: {declining_pages:,} ({pct_declining:.1f}%)")
print(f"Average 90-day impressions per page: {avg_impressions:,.0f}")
# Out:
# Cloning into 'flyrank_mlengineer'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 119 (delta 34), reused 96 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 6.68 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# Total pages in starter dataset: 30,000
# Pages with declining traffic trend: 16,262 (54.2%)
# Average 90-day impressions per page: 5,200

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#This project identifies historical patterns associated with future organic search performance decline to create a ranked list of pages for human review. While I can claim that a page exhibits higher estimated risk, that observable signals correlate with that risk, and that the machine learning approach outperforms a simple baseline under our validation methodology, I cannot claim causation. Specifically, I cannot state that a specific factor caused a decline, that updating a page will guarantee higher traffic or rankings, or that the model predicts Google's algorithm. Ultimately, the system must be described strictly as a machine learning decision support system that ranks pages by estimated performance decline risk to help human reviewers prioritize their work, not as an AI that predicts search rankings or automatically determines page success.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
